# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# ## 1.条形图bar

# %%
a = ['流浪地球','疯狂的外星人','飞驰人生','大黄蜂','熊出没·原始时代','新喜剧之王']
b = [38.13,19.85,14.89,11.36,6.47,5.93]

plt.figure(figsize=(20,8),dpi=80)

# 会返回一个对象(列表,装着每一个条形图)
# 16位进制的颜色
rects = plt.bar(range(len(a)),b,width=0.3,color=['r','g','b','r','g','b'])

plt.xticks(range(len(a)),a)
plt.yticks(range(0,41,5),range(0,41,5))

# 在条形图上加标注（水平）
for rect in rects:
    #获取条形图的高度(y值)
    height = rect.get_height()
    x = rect.get_x()
    
    plt.text(rect.get_x()+rect.get_width()/2,height+0.5,'{}亿'.format(height),ha='center')

plt.show()

# %%
# 绘制横向条形图barh

a = ['流浪地球','疯狂的外星人','飞驰人生','大黄蜂','熊出没·原始时代','新喜剧之王']
b = [38.13,19.85,14.89,11.36,6.47,5.93]

plt.figure(figsize=(20,8),dpi=80)

rects = plt.barh(range(len(a)),b,height=0.5,color=['r','g','b','r','g','b'])

plt.yticks(range(len(a)),a,rotation=45)

# 在条形图上加标注(垂直居中)
for rect in rects:
    width = rect.get_width()
    y = rect.get_y()
    plt.text(width+0.3,rect.get_y()+0.5/2,'{}亿'.format(width),va='center')
 
plt.show()

# %%
# 绘制并列和罗列条形图

import numpy as np
index = np.arange(4)

plt.figure(figsize=(20,8),dpi=80)

BJ = [50,55,53,60]
Sh = [44,66,55,41]

# 并列条形图
# plt.bar(index,BJ,width=0.3)
# plt.bar(index+0.3,Sh,width=0.3,color='g')

# plt.xticks(index+0.3/2,index)

# 罗列条形图
plt.bar(index,BJ,width=0.3)
plt.bar(index,Sh,bottom=BJ,width=0.3,color='g')

plt.show()

# %% [markdown]
# ## 2.直方图hist

# %%
import random

# 1）准备数据
# time = [random.randint(90,180) for i in range(50)]
time = [131,98, 125, 131, 124, 139, 131, 117, 128, 108, 135, 138, 131, 102, 107, 114,
        119, 128, 121, 142, 127, 130, 124, 101, 110, 116, 117, 110, 128, 128, 115,  99, 
        136, 126, 134,  95, 138, 117, 111,78, 132, 124, 113, 150, 110, 117,  86,  95, 144, 
        105, 126, 130,126, 130, 126, 116, 123, 106, 112, 138, 123,  86, 101,  99, 136,123,
        117, 119, 105, 137, 123, 128, 125, 104, 109, 134, 125, 127,105, 120, 107, 129, 116,
        108, 132, 103, 136, 118, 102, 120, 114,105, 115, 132, 145, 119, 121, 112, 139, 125,138, 
        109, 132, 134,156, 106, 117, 127, 144, 139, 139, 119, 140,  83, 110, 102,123,
        107, 143, 115, 136, 118, 139, 123, 112, 118, 125, 109, 119, 133,112, 114, 122, 109, 
        106, 123, 116, 131, 127, 115, 118, 112, 135,115, 146, 137, 116, 103, 144,  83, 123, 
        111, 110, 111, 100, 154,136, 100, 118, 119, 133, 134, 106, 129, 126, 110, 111, 109, 
        141,120, 117, 106, 149, 122, 122, 110, 118, 127, 121, 114, 125, 126,114, 140, 103, 
        130, 141, 117, 106, 114, 121, 114, 133, 137,  92,121, 112, 146,  97, 137, 105,  98, 
        117, 112,  81,  97, 139, 113,134, 106, 144, 110, 137, 137, 111, 104, 117, 100, 111,
        101, 110,105, 129, 137, 112, 120, 113, 133, 112,  83,  94, 146, 133, 101,131, 116, 
        111,  84, 137, 115, 122, 106, 144, 109, 123, 116, 111,111, 133, 150]
# print(time)

# 2）创建画布
plt.figure(figsize=(20, 8), dpi=100)

# 3）设置组距
distance = 2
group_num = int((max(time)-min(time))/distance)

# 4）绘制直方图(density密度)
plt.hist(time,bins=group_num,density=1)

# 修改x轴刻度显示
plt.xticks(range(min(time),max(time)+1)[::distance])

# 添加网格显示
plt.grid(linestyle="--",alpha=0.5)

# 添加x, y轴描述信息
plt.xlabel("电影时长大小")
plt.ylabel("电影的数据量")

# 5）显示图像
plt.show()

# %% [markdown]
# ## 3.饼图pie

# %%
"""
绘制饼图
x : (每一块)的比例,如果sum(x)>1，会将多出的部分进行均分；
explode: (每一块)离开中心距离
labels: (每一块)饼图外侧显示的说明文字；
labeldistance:设置标签文本距圆心位置，1.1表示1.1倍半径
autopct：控制饼图内百分比设置
shadow：设置是否有阴影
startangle：起始绘制角度,默认图是从x轴正方向逆时针画起,如设定=90则从y轴正方向画起；
pctdistance：类似于labeldistance,指定autopct的位置刻度,默认值为0.6；
返回值:
patches : matplotlib.patches.Wedge列表(扇形实例)
l_text：label matplotlib.text.Text列表(标签实例)
p_text：label matplotlib.text.Text列表(百分比标签实例)
"""

# %%
plt.figure(figsize=(20, 8), dpi=100)

# 各部分标签
label_list = ["第一部分", "第二部分", "第三部分"] 

# 各部分占比大小
size = [55, 35, 10]  

# 各部分颜色
color = ["red", "green", "blue"] 

# 各部分突出值
explode = [0, 0.05, 0] 

# patches 扇形实例，饼图由三个扇形组成的 ；l_text 标签实例(外部标签)，p_text 百分比标签实例（内部标签）
patches, l_text, p_text = plt.pie(size, 
                                  explode=explode, 
                                  colors=color, 
                                  labels=label_list, 
                                  labeldistance=1.1, 
                                  autopct="%.2f%%", 
                                  shadow=True, 
                                  startangle=90,
                                  pctdistance=0.6)

# 改变扇形颜色
num = 0 
for i in patches:
    num +=1 
    if num == 2:  
        i.set_color('pink')
        break
  
plt.show()

# %% [markdown]
# ## 4.气泡图

# %%
import numpy as np

x = range(1,32)
y = [11,17,16,11,12,11,12,6,6,7,8,9,12,15,14,17,18,21,16,17,20,14,15,15,15,19,21,22,22,22,23]

plt.figure(figsize=(20,8),dpi=80)

# 设置大小
size = np.random.randint(0, 100, 31)

plt.scatter(x,y,label= '3月份',alpha=0.5,s=size,c='red')

# 调整坐标轴的刻度
x_ticks_labels = ['3月{}日'.format(i) for i in x]
plt.xticks(x[::3],x_ticks_labels[::3],rotation=45)

y_ticks_labels = ['{}°C'.format(i) for i in range(min(y),max(y)+1)]
plt.yticks(range(min(y),max(y)+1),y_ticks_labels)

# 设置坐标轴标题
plt.xlabel('日期')
plt.ylabel('温度')

plt.legend()
plt.show()

# %% [markdown]
# ## 扩展

# %%
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec

np.random.seed(19680801)

dt = 0.01
t = np.arange(0,10,dt)
nse = np.random.randn(len(t))
r = np.exp(-t/0.05)

cnse = np.convolve(nse,r) * dt
cnse = cnse[:len(t)]
s = 0.1 * np.sin(2*np.pi*t) + cnse

plt.subplot(211)
plt.plot(t,s)

plt.subplot(212)
plt.psd(s,512,1/dt)

plt.show()
